# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="center">
#                 <font color="#21619" size=6px>
#                     <b>  Prediction of Employee Attrition
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=4.5px>
#                     <b>
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=2px>
#                     <b>
#                     <br>
#                     </b>
#                 </font>
#             </div>
#             <div align="center">
#                 <font color="#21619" size=4px>
#                     <b>  Data analysis and Machine Learning Model Building
#                     </b>
#                 </font>
#             </div>
#          </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4.8px>
#                     <b>  Author
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# * Roshankumar S
#
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Problem Statement
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# Employee attrition is a significant concern for organizations, leading to increased recruitment costs and potential loss of valuable talent. The aim of this project is to develop a predictive model that can effectively forecast whether an employee is likely to leave the company or not. By harnessing the power of machine learning, I seek to provide organizations with a data-driven solution to proactively identify employees at risk of attrition. This predictive model will enable companies to implement targeted retention strategies, ultimately reducing attrition rates and maintaining a motivated and productive workforce.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Objective
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# The primary objective of this project is to develop a robust machine learning model for predicting employee attrition. I aim to create and evaluate predictive models, perform feature selection and engineering, fine-tune hyperparameters, preprocess data, scale features, and provide actionable insights. By achieving these objectives, I seek to empower organizations to proactively manage employee attrition, reduce recruitment costs, and maintain a motivated and productive workforce.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Classification Models
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# * **Logistic Regression**
# * **K-Nearest Neighbors**
# * **Naive Bayes**
# * **Decision Tree Classifier**
# * **Random Forest Classifier**
# * **Ada Boost Classifier**
# * **Gradient Boost Classifier**
# * **Xtreme Gradient Boost Classifier**
#
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Data Description
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# The data set consists of complete educational details of students right from their schooling to MBA and previous work experience. Our main objective is to predict the Salary of the students based on the info available
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Data Dictionary
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# - **`Age`**: The age of the employee.
# - **`Attrition`**: The target variable indicating whether an employee has left the company (`Yes`) or not (`No`).
# - **`BusinessTravel`**: The frequency of business travel, categorized as `Travel_Rarely`, `Travel_Frequently`, or `Non-Travel`.
# - **`DailyRate`**: The daily rate of pay for the employee.
# - **`Department`**: The department in which the employee works.
# - **`DistanceFromHome`**: The distance in miles from the employee's home to the workplace.
# - **`Education`**: The level of education of the employee.
#   - 1: 'Below College'
#   - 2: 'College'
#   - 3: 'Bachelor'
#   - 4: 'Master'
#   - 5: 'Doctor'
# - **`EducationField`**: The field of education of the employee.
# - **`EmployeeCount`**: A count of employees (usually 1 for all records).
# - **`EmployeeNumber`**: A unique identifier for each employee.
# - **`EnvironmentSatisfaction`**: The satisfaction level of the employee with their working environment.
#   - 1: 'Low'
#   - 2: 'Medium'
#   - 3: 'High'
#   - 4: 'Very High'
# - **`Gender`**: The gender of the employee.
# - **`HourlyRate`**: The hourly rate of pay for the employee.
# - **`JobInvolvement`**: The job involvement level of the employee.
#   - 1: 'Low'
#   - 2: 'Medium'
#   - 3: 'High'
#   - 4: 'Very High'
# - **`JobLevel`**: The job level or position of the employee within the company.
# - **`JobRole`**: The role or job title of the employee.
# - **`JobSatisfaction`**: The satisfaction level of the employee with their job.
#   - 1: 'Low'
#   - 2: 'Medium'
#   - 3: 'High'
#   - 4: 'Very High'
# - **`MaritalStatus`**: The marital status of the employee.
# - **`MonthlyIncome`**: The monthly income of the employee.
# - **`MonthlyRate`**: The monthly rate.
# - **`NumCompaniesWorked`**: The number of companies the employee has worked for in the past.
# - **`Over18`**: A binary indicator for whether the employee is over 18 years old (`Yes` or `No`).
# - **`OverTime`**: A binary indicator for whether the employee works overtime (`Yes` or `No`).
# - **`PercentSalaryHike`**: The percentage increase in salary.
# - **`PerformanceRating`**: The performance rating of the employee.
#   - 1: 'Low'
#   - 2: 'Good'
#   - 3: 'Excellent'
#   - 4: 'Outstanding'
# - **`RelationshipSatisfaction`**: The satisfaction level of the employee with their relationships at work.
#   - 1: 'Low'
#   - 2: 'Medium'
#   - 3: 'High'
#   - 4: 'Very High'
# - **`StandardHours`**: The standard number of working hours.
# - **`StockOptionLevel`**: The level of stock options granted to the employee.
# - **`TotalWorkingYears`**: The total number of years the employee has worked.
# - **`TrainingTimesLastYear`**: The number of training sessions attended by the employee last year.
# - **`WorkLifeBalance`**: The work-life balance rating of the employee.
#   - 1: 'Bad'
#   - 2: 'Good'
#   - 3: 'Better'
#   - 4: 'Best'
# - **`YearsAtCompany`**: The number of years the employee has worked at the current company.
# - **`YearsInCurrentRole`**: The number of years the employee has been in their current role.
# - **`YearsSinceLastPromotion`**: The number of years since the employee's last promotion.
# - **`YearsWithCurrManager`**: The number of years the employee has been with their current manager.

# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Content
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# * ##### [1. Import Libraries](#libraries)
# * ##### [2. Data Understanding](#understanding)
# * ##### [3. Explorator Data Analysis](#eda)
#   * ##### [3.1 Univariate analysis of cateogrical features (Count Plots)](#categorical)
#   * ##### [3.2 Univariate analysis of numerical features (Box Plots)](#numerical)
#   * ##### [3.3 Distribution of Target attribute](#target)
#   * ##### [3.4 Relation between Target and numerical features](#numvstarget)
#   * ##### [3.5 Heat map of Correlation among numerical features](#correlation)
#   * ##### [3.6 Statistical testing of correlation between target and numerical features (ANOVA)](#anova)
# * ##### [4. Data Preprocessing](#preprocessing)
#   * ##### [4.1 Treating outliers using capping method](#outlier)
#   * ##### [4.2 Transformation of numerical features using Yeo-Johnson method](#transformation)
#   * ##### [4.3 Encoding categorical features using Label encoding](#encoding)
#   * ##### [4.4 Feature Engineering](#engineering)
#   * ##### [4.5 Splitting dataset into train set and test set](#split)
#   * ##### [4.6 Comparison of train set and test set](#testvstrain)
# * ##### [5. Model Building](#model)
# * ##### [6. Model Comparison](#comparison)
# * ##### [7. Model Evaluation](#evaluation)
#   * ##### [7.1 Accuracy Score](#accuracy)
#   * ##### [7.2 Classificationi Report](#report)
#   * ##### [7.3 Confusion Matrix](#confusion)
#   * ##### [7.4 Cohen Kappa Score](#cohen)
#   * ##### [7.5 ROC-AUC curve](#rocauc)
#   * ##### [7.6 Youden's table](#youden)
# * ##### [8. Statistical Summary of Logistic Regression model](#stats)
#   * ##### [8.1 Significant Features by analyzing P-values](#features)
# * ##### [9. Feature selection using Recursive Feature Selection](#rfe)
# * ##### [10. Hyperparameter Tuning using Grid Search CV](#gridsearchcv)
# * ##### [11. Scaling numerical features using Standard Scaler](#scaling)
# * ##### [12. Interpretation](#interpretation)
# * ##### [13. Overall Fit of the model](#fit)
# * ##### [14. Conclusion](#conclusion)

# %% [markdown]
# <a id="libraries"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Import libraries
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Import numpy for mathematical operations
import numpy as np

# Import pandas for manipulating and retrieving dataset
import pandas as pd

# Import matplotlib for visualization tools
import matplotlib.pyplot as plt

# Import seaborn for advanced visualization tools
import seaborn as sns

# Import stats module to perform statistical operations
from scipy import stats

# Import Power Transformer for transformation
from sklearn.preprocessing import PowerTransformer

# Import Label encoder for encoding categories
from sklearn.preprocessing import LabelEncoder

# Import train test split to split the dataset for training and testing
from sklearn.model_selection import train_test_split

# Import Standard Scaler for scaling numerical features
from sklearn.preprocessing import StandardScaler

# Import Logistic Regression model
from sklearn.linear_model import LogisticRegression

# Import KNN model
from sklearn.neighbors import KNeighborsClassifier

# Import Naive Bayes model
from sklearn.naive_bayes import GaussianNB

# Import Decision Tree classifier model
from sklearn.tree import DecisionTreeClassifier

# Import Random Forest Classifier model
from sklearn.ensemble import RandomForestClassifier

# Import Ada Boost Classifier model
from sklearn.ensemble import AdaBoostClassifier

# Import Gradient Boosting Classifier model
from sklearn.ensemble import GradientBoostingClassifier

# Import Xtreme Gradient Boost Classifier model
from xgboost import XGBClassifier

# Import statsmodels for OLS model
import statsmodels.api as sm

# Import metrics for evaluation
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,cohen_kappa_score,roc_auc_score,roc_curve

# Import Recursieve Feature Selector for feature selection
from sklearn.feature_selection import RFECV

# Import GridSearchCv for Hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import data from csv file into dataframe
df=pd.read_csv("data_set.csv")

# Display top 5 observations of the dataset
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# <a id="understanding"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Data Understanding
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# Display number of rows and columns
print("Number of rows: ",df.shape[0])
print("Number of columns: ",df.shape[1])
# Out:
# Number of rows:  917
# Number of columns:  35

# %%
# Display basic information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917 entries, 0 to 916
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       917 non-null    int64
#  1   Attrition                 917 non-null    object
#  2   BusinessTravel            917 non-null    object
#  3   DailyRate                 917 non-null    int64
#  4   Department                917 non-null    object
#  5   DistanceFromHome          917 non-null    int64
#  6   Education                 917 non-null    int64
#  7   EducationField            917 non-null    object
#  8   EmployeeCount             917 non-null    int64
#  9   EmployeeNumber            917 non-null    int64
#  10  EnvironmentSatisfaction   917 non-null    int64
#  11  Gender                    917 non-null    object
#  12  HourlyRate                917 non-null    int64
#  13  JobInvolvement            917 non-null    int64
# ...

# %% [markdown]
# * We have to convert datatypes of categorical columns which are present as numerical.

# %%
# Convert datatypes of categorical columns from numerical to object
for column in ["Education","EnvironmentSatisfaction","JobInvolvement","JobSatisfaction","PerformanceRating","RelationshipSatisfaction","WorkLifeBalance","JobLevel","NumCompaniesWorked","StockOptionLevel"]:
    df[column] = df[column].astype(object)

# %%
# Descriptive statistics of numerical columns
df.describe()
# Out:
#               Age    DailyRate  DistanceFromHome  EmployeeCount  \
# count  917.000000   917.000000        917.000000          917.0
# mean    36.938931   785.711014          9.294438            1.0
# std      8.984981   401.902148          8.092566            0.0
# min     18.000000   102.000000          1.000000            1.0
# 25%     30.000000   444.000000          2.000000            1.0
# 50%     36.000000   772.000000          7.000000            1.0
# 75%     43.000000  1141.000000         14.000000            1.0
# max     60.000000  1498.000000         29.000000            1.0
#
#        EmployeeNumber  HourlyRate  MonthlyIncome   MonthlyRate  \
# count      917.000000  917.000000     917.000000    917.000000
# mean      1413.466739   66.231189    6452.293348  14428.468920
# std        388.606884   20.237536    4685.137761   7188.332799
# min          1.000000   30.000000    1051.000000   2097.000000
# 25%       1084.000000   49.000000    2933.000000   8018.000000
# ...

# %%
# Drop numerical columns which contributes no information
df.drop(["EmployeeNumber","EmployeeCount","StandardHours"],axis=1,inplace=True)

# %%
# Descriptive statistics of cateogorical columns
df.describe(include=object)
# Out:
#        Attrition BusinessTravel              Department  Education  \
# count        917            917                     917        917
# unique         2              3                       3          5
# top           No  Travel_Rarely  Research & Development          3
# freq         763            648                     597        359
#
#        EducationField  EnvironmentSatisfaction Gender  JobInvolvement  \
# count             917                      917    917             917
# unique              6                        4      2               4
# top     Life Sciences                        4   Male               3
# freq              385                      290    550             532
#
#         JobLevel          JobRole  JobSatisfaction MaritalStatus  \
# count        917              917              917           917
# unique         5                9                4             3
# top            1  Sales Executive                4       Married
# ...

# %%
# Drop category with single class
df.drop("Over18",axis=1,inplace=True)

# %%
# Split dataset into numerical and categorical
df_num = df.select_dtypes(include=np.number)
df_cat = df.select_dtypes(include=object)

# %%
# Find unique classes for each categorical columns
classes = []
for col in df.select_dtypes(include=object).columns:
    classes.append(df[col].nunique())

# %%
pd.DataFrame({"Number of categories":classes},index=df.select_dtypes(include=object).columns)
# Out:
#                           Number of categories
# Attrition                                    2
# BusinessTravel                               3
# Department                                   3
# Education                                    5
# EducationField                               6
# EnvironmentSatisfaction                      4
# Gender                                       2
# JobInvolvement                               4
# JobLevel                                     5
# JobRole                                      9
# JobSatisfaction                              4
# MaritalStatus                                3
# NumCompaniesWorked                          10
# OverTime                                     2
# PerformanceRating                            2
# RelationshipSatisfaction                     4
# StockOptionLevel                             4
# WorkLifeBalance                              4

# %%
# Checking for missing values
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# <a id="eda"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Exploratory Data Analysis
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="categorical"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Count plots for categorical data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
fig,subplots = plt.subplots(10,2,figsize=(20,40))
for col,axis in zip(df_cat.columns,subplots.flatten()):
    plt.title(col)
    sns.countplot(df_cat[col],ax=axis)
plt.show()

# %% [markdown]
# <a id="numerical"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Box Plots for numerical data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
fig,subplots = plt.subplots(7,2,figsize=(20,40))
for col,axis in zip(df_num.columns,subplots.flatten()):
    plt.title(col)
    sns.boxplot(y=df_num[col],ax=axis)
plt.show()

# %% [markdown]
# * We can observe outliers present in some of the columns.

# %% [markdown]
# <a id="target"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Distribution of Target feature
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
sns.countplot(df["Attrition"])
plt.show()

# %% [markdown]
# * The target column is unevenly distributed.
# * We can use SMOTE to introduce synthetic data into our dataset.

# %% [markdown]
# <a id="numvstarget"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Distribution of numerical columns with respect to target column
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
fig,subplots = plt.subplots(7,2,figsize=(20,40))
for col,axis in zip(df_num.columns,subplots.flatten()):
    plt.title(col)
    sns.boxplot(y=df_num[col],x=df["Attrition"],ax=axis)
plt.show()

# %% [markdown]
# * We can see Hourly rate, Training times last year of both classes of target column (Yes and No) have same distribution.
# * We can drop these columns.

# %%
for i in df_num.columns:
    plt.figure(figsize=(12,4))
    plt.subplot(121)
    plt.title(i+" (Attrtion=Yes)")
    sns.distplot(df_num[i][df["Attrition"]=="Yes"],color="b")
    plt.subplot(122)
    plt.title(i+" (Attrtion=No)")
    sns.distplot(df_num[i][df["Attrition"]=="No"],color="g")
    plt.show()

# %% [markdown]
# <a id="correlation"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Heat map of correlation
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_num.corr(),annot=True)
plt.show()

# %% [markdown]
# * We can see monthly income and Yearsincurrentrole are highly correlated.
# * We can see Yearsincurrent role and years in company are highly correlated.
# * We can perform feature engineering to convert two columns to one.

# %%
df_num.drop(["HourlyRate","TrainingTimesLastYear"],axis=1,inplace=True)

# %% [markdown]
# <a id="anova"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  ANOVA test for correlationi between target and numerical features
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
for col in df_num.columns:
    yes = df_num[col][df["Attrition"]=="Yes"].values
    no = df_num[col][df["Attrition"]=="No"].values
    statistic,p_value = stats.f_oneway(yes,no)
    print("P-value for correlation between Attrition and",col," : ",round(p_value,2))
# Out:
# P-value for correlation between Attrition and Age  :  0.0
# P-value for correlation between Attrition and DailyRate  :  0.14
# P-value for correlation between Attrition and DistanceFromHome  :  0.04
# P-value for correlation between Attrition and MonthlyIncome  :  0.0
# P-value for correlation between Attrition and MonthlyRate  :  0.67
# P-value for correlation between Attrition and PercentSalaryHike  :  0.42
# P-value for correlation between Attrition and TotalWorkingYears  :  0.0
# P-value for correlation between Attrition and YearsAtCompany  :  0.0
# P-value for correlation between Attrition and YearsInCurrentRole  :  0.0
# P-value for correlation between Attrition and YearsSinceLastPromotion  :  0.44
# P-value for correlation between Attrition and YearsWithCurrManager  :  0.0

# %% [markdown]
# * Since P-value of monthly Rate, percent salary hike and years since last promotion are very much higher than 0.05, we can drop it.
# * Because, those columns have no correlation with the target column.

# %%
df_num.drop(["MonthlyRate","PercentSalaryHike","YearsSinceLastPromotion"],axis=1,inplace=True)

# %% [markdown]
# <a id="preprocessing"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Data Preprocessing
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="outlier"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Outlier Treatment
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### Display outliers present in each numerical columns

# %%
outlier_values = []
for i in df_num.columns:
    Q1 = np.quantile(df_num[i],0.25)
    Q3 = np.quantile(df_num[i],0.75)
    IQR = Q3-Q1
    ul = Q3+(IQR*1.5)
    ll = Q1-(IQR*1.5)
    outlier = df_num[(df_num[i]<ll) | (df_num[i]>ul)]
    outlier_values.append(outlier[i].values)

# %%
outliers = pd.DataFrame({"Outliers":outlier_values},index=[df_num.columns])
outliers
# Out:
#                                                                   Outliers
# Age                                                                     []
# DailyRate                                                               []
# DistanceFromHome                                                        []
# HourlyRate                                                              []
# MonthlyIncome            [16856, 19859, 18430, 17639, 16752, 19246, 171...
# MonthlyRate                                                             []
# PercentSalaryHike                                                       []
# TotalWorkingYears        [34, 30, 40, 29, 35, 31, 33, 31, 29, 32, 30, 3...
# TrainingTimesLastYear    [0, 0, 5, 5, 0, 6, 6, 5, 6, 0, 5, 0, 6, 6, 6, ...
# YearsAtCompany           [34, 24, 26, 31, 20, 31, 26, 19, 21, 21, 32, 2...
# YearsInCurrentRole        [15, 16, 16, 15, 16, 17, 15, 15, 15, 17, 17, 16]
# ...

# %% [markdown]
# ### Outliers treatment using capping method

# %%
for i in df_num.columns:
    Q1 = np.quantile(df_num[i],0.25)
    Q3 = np.quantile(df_num[i],0.75)
    IQR = Q3-Q1
    ul = Q3+(IQR*1.5)
    ll = Q1-(IQR*1.5)
    for j in df_num.index:
        if df_num.loc[j,i]<ll:
            df_num.loc[j,i]=ll
        elif df_num.loc[j,i]>ul:
            df_num.loc[j,i] = ul

# %% [markdown]
# <a id="transformation"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Transformation using Yeo-Johnson method
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Check for skewness in numerical columns

# %%
df_num.skew()
# Out:
# Age                        0.392743
# DailyRate                  0.044223
# DistanceFromHome           0.926858
# HourlyRate                -0.057398
# MonthlyIncome              1.129219
# MonthlyRate                0.007792
# PercentSalaryHike          0.840310
# TotalWorkingYears          0.900584
# TrainingTimesLastYear      0.102317
# YearsAtCompany             0.885027
# YearsInCurrentRole         0.799987
# YearsSinceLastPromotion    1.281278
# YearsWithCurrManager       0.800280
# dtype: float64

# %% [markdown]
# * Since most of the columns are skewed we have to perform transformation.
# * We can perform Yeo-Johnson transformation since the columns have zeroes.

# %% [markdown]
# ### Transformation of numerical columns using Yeo-Johnson

# %%
transformer = PowerTransformer()

# %%
transformed = pd.DataFrame(transformer.fit_transform(df_num),index=df_num.index,columns=df_num.columns)

# %%
transformed.skew()
# Out:
# Age                       -0.008418
# DailyRate                 -0.183592
# DistanceFromHome          -0.016343
# HourlyRate                -0.113342
# MonthlyIncome              0.023638
# MonthlyRate               -0.188394
# PercentSalaryHike          0.113116
# TotalWorkingYears         -0.023769
# TrainingTimesLastYear     -0.023792
# YearsAtCompany            -0.042353
# YearsInCurrentRole        -0.067333
# YearsSinceLastPromotion    0.183510
# YearsWithCurrManager      -0.063313
# dtype: float64

# %%
df_num = transformed

# %% [markdown]
# <a id="encoding"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Encode categorical columns using Label Encoder
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
encoder = LabelEncoder()

# %%
for col in df_cat.columns:
    df_cat[col] = encoder.fit_transform(df_cat[[col]])

# %%
# Convert datatype of categorical columns from object to integer
for i in df_cat.columns:
    df_cat[i] = df_cat[i].astype(int)

# %%
df_cat.head()
# Out:
#    BusinessTravel  Department  Education  EducationField  \
# 0               2           2          1               1
# 1               1           1          0               1
# 2               2           1          1               4
# 3               1           1          3               1
# 4               2           1          0               3
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobRole  \
# 0                        1       0               2         1        7
# 1                        2       1               1         1        6
# 2                        3       1               1         0        2
# 3                        3       0               2         0        6
# 4                        0       1               2         0        2
#
#    JobSatisfaction  MaritalStatus  NumCompaniesWorked  OverTime  \
# 0                3              2                   8         1
# 1                1              1                   1         0
# ...

# %% [markdown]
# <a id="engineering"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Feature Engineering
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df_num["PercentOfYearsInCurrentRole"] = df_num["YearsInCurrentRole"]/df_num["YearsAtCompany"]
df_num.drop(["YearsInCurrentRole","YearsAtCompany"],axis=1,inplace=True)

# %%
# Drop target column
df_cat.drop("Attrition",axis=1,inplace=True)

# %% [markdown]
# <a id="split"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Train-Test Split
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Define target and independent attributes

# %%
X = pd.concat([df_num,df_cat],axis=1)
y = df["Attrition"].map({"Yes":1,"No":0})

# %% [markdown]
# ### Split the dataset into train set and test set

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (733, 24)
# (184, 24)
# (733,)
# (184,)

# %% [markdown]
# <a id="testvstrain"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Check if train set and test set are representation of overall dataset
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(12,5))
plt.subplot(121)
sns.countplot(y_train)
plt.subplot(122)
sns.countplot(y_test)
plt.show()

# %% [markdown]
# * Since the distribution of train dataset and test dataset are similar, we can conclude that both train and test representative of the overall data.

# %% [markdown]
# <a id="model"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Model Building
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Train models using various classification algorithms

# %%
lr = LogisticRegression().fit(X_train,y_train)
knn = KNeighborsClassifier(n_neighbors=5).fit(X_train,y_train)
nb = GaussianNB().fit(X_train,y_train)
dt = DecisionTreeClassifier().fit(X_train,y_train)
rf = RandomForestClassifier().fit(X_train,y_train)
ab = AdaBoostClassifier().fit(X_train,y_train)
gb = GradientBoostingClassifier().fit(X_train,y_train)
xgb = XGBClassifier().fit(X_train,y_train)

# %% [markdown]
# <a id="comparison"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Models Comparison
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
train_scores = []
test_scores = []
models = [lr,knn,nb,dt,rf,ab,gb,xgb]
for model in models:
    y_pred_test = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    test_scores.append(accuracy_score(y_test,y_pred_test))
    train_scores.append(accuracy_score(y_train,y_pred_train))

# %%
model_performance = pd.DataFrame(index=["Logistic Regression","K-Nearest Neighbors","Naive Bayes","Decision Tree",
                                        "Random Forest","Ada Boost","Gradient Boost","XGBoost"],
                                 data={"Train accuracy":train_scores,"Test accuracy":test_scores})
model_performance
# Out:
#                      Train accuracy  Test accuracy
# Logistic Regression        0.879945       0.880435
# K-Nearest Neighbors        0.867667       0.831522
# Naive Bayes                0.841746       0.842391
# Decision Tree              1.000000       0.804348
# Random Forest              1.000000       0.853261
# Ada Boost                  0.897681       0.913043
# Gradient Boost             0.964529       0.880435
# XGBoost                    0.949523       0.885870

# %% [markdown]
# * Since ADAboost as performed the  best in test set, we can use ADA Boost model for our prediction.
# * The overall accuracy of the model is around 91%, which is quite good.

# %% [markdown]
# <a id="evaluation"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Models Evaluation
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
adaboost_model = AdaBoostClassifier().fit(X_train,y_train)
y_pred = adaboost_model.predict(X_test)

# %% [markdown]
# <a id="accuracy"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Accuracy Score
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print("Accuracy score: ",accuracy_score(y_test,y_pred))
# Out:
# Accuracy score:  0.9130434782608695

# %% [markdown]
# <a id="report"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Classification Report
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       152
#            1       0.94      0.53      0.68        32
#
#     accuracy                           0.91       184
#    macro avg       0.93      0.76      0.81       184
# weighted avg       0.92      0.91      0.90       184

# %% [markdown]
# * Precision is percent of correctly predicted positives among total predicted positives.
# * Recall is percent of positives among the actual positives which are correctly predicted.

# %% [markdown]
# <a id="confusion"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Confusion Matrix
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[150,   2],
#        [ 19,  13]])

# %%
sns.heatmap(data=cm,annot=True,cbar=False)
plt.show()

# %% [markdown]
# <a id="cohen"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Cohen Kappa Score
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
cohen_kappa_score(y_test,y_pred)
# Out:
# 0.6341948310139165

# %% [markdown]
# * The value of cohen Kappa score lies between -1 to +1.
# * Since the value of the model is around +0.6, it is a well fit and generalized model.

# %% [markdown]
# <a id="rocauc"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Receiver Operating Characteristic - Area Under Curve
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
y_pred_proba = [i[1] for i in adaboost_model.predict_proba(X_test)]

# %%
fpr,tpr,thresholds = roc_curve(y_test,y_pred_proba)
plt.plot(fpr,tpr)
plt.xlim([0,1])
plt.ylim([0,1])
plt.plot([0,1],"r--")
plt.text(x=0.6,y=0.2,s=roc_auc_score(y_test,y_pred_proba))
plt.title("ROC-AUC curve")
plt.xlabel("False Positive Rates")
plt.ylabel("True Positive Rates")
plt.show()

# %% [markdown]
# <a id="youden"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Youden's Table
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
youden_table = pd.DataFrame(data={"FPR":fpr,"TPR":tpr,"Threshold":thresholds})
youden_table["Difference"] = youden_table.TPR-youden_table.FPR
youden_table.sort_values("Difference",ascending=False)
# Out:
#          FPR      TPR  Threshold  Difference
# 6   0.039474  0.59375   0.497623    0.554276
# 10  0.105263  0.65625   0.494373    0.550987
# 8   0.078947  0.62500   0.495664    0.546053
# 4   0.019737  0.56250   0.499460    0.542763
# 20  0.276316  0.81250   0.488786    0.536184
# 2   0.000000  0.53125   0.500533    0.531250
# 5   0.039474  0.56250   0.498413    0.523026
# 16  0.230263  0.75000   0.490469    0.519737
# 9   0.105263  0.62500   0.495087    0.519737
# 7   0.078947  0.59375   0.495948    0.514803
# 3   0.019737  0.53125   0.499659    0.511513
# 18  0.269737  0.78125   0.489576    0.511513
# 19  0.276316  0.78125   0.489423    0.504934
# 14  0.217105  0.71875   0.490585    0.501645
# 15  0.230263  0.71875   0.490529    0.488487
# 17  0.269737  0.75000   0.489635    0.480263
# 12  0.210526  0.68750   0.491083    0.476974
# 13  0.217105  0.68750   0.490927    0.470395
# 11  0.210526  0.65625   0.491087    0.445724
# 22  0.447368  0.87500   0.485145    0.427632
# ...

# %% [markdown]
# * Since the difference for 0.49 is higher, we can consider 0.49 as the threshold.

# %% [markdown]
# <a id="stats"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Statistical Summary of Logistic Regression model
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
X_c = sm.add_constant(X)
Xc_train,Xc_test,yc_train,yc_test = train_test_split(X_c,y,test_size=0.2,random_state=2)
logreg = sm.Logit(yc_train,Xc_train).fit()
logreg.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.339124
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              Attrition   No. Observations:                  733
# Model:                          Logit   Df Residuals:                      708
# Method:                           MLE   Df Model:                           24
# Date:                Sun, 03 Sep 2023   Pseudo R-squ.:                  0.2467
# Time:                        06:58:26   Log-Likelihood:                -248.58
# converged:                       True   LL-Null:                       -329.99
# Covariance Type:            nonrobust   LLR p-value:                 1.320e-22
# ...
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# <a id="features"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>  Significant Features
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Significant features with p-values less than 0.05

# %%
# P-values of all columns
round(logreg.pvalues,2)[round(logreg.pvalues,2)<0.05]
# Out:
# const                       0.00
# DistanceFromHome            0.02
# MonthlyIncome               0.00
# TotalWorkingYears           0.03
# Department                  0.00
# EnvironmentSatisfaction     0.00
# JobInvolvement              0.01
# JobLevel                    0.01
# JobRole                     0.03
# JobSatisfaction             0.00
# MaritalStatus               0.01
# NumCompaniesWorked          0.00
# OverTime                    0.00
# RelationshipSatisfaction    0.01
# dtype: float64

# %% [markdown]
# <a id="rfe"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Recursive Feature Selection
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
rfecv = RFECV(estimator=AdaBoostClassifier(random_state=2),cv=10,scoring="accuracy").fit(X_train,y_train)

# %%
features = pd.DataFrame(index=X.columns,data={"Rank":rfecv.ranking_})
important_features = features[features.Rank==1].index
important_features
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'MonthlyIncome',
#        'TotalWorkingYears', 'YearsWithCurrManager',
#        'PercentOfYearsInCurrentRole', 'BusinessTravel', 'Department',
#        'EnvironmentSatisfaction', 'JobInvolvement', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'NumCompaniesWorked', 'OverTime',
#        'RelationshipSatisfaction', 'WorkLifeBalance'],
#       dtype='object')

# %%
# Selected features
X_important = X[important_features]

# %%
X_train,X_test,y_train,y_test = train_test_split(X_important,y,test_size=0.2,random_state=2)

# %%
adaboost_model = AdaBoostClassifier().fit(X_train,y_train)
y_pred = adaboost_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9021739130434783

# %% [markdown]
# * As we can see, the accuracy of the overall model has been reduced after doing feature selection.
# * So can ignore feature selection.

# %% [markdown]
# <a id="gridsearchcv"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Hyperparameter tuning using GridSearchCV
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
tune_parameters = {"learning_rate":[0.1,0.01,0.001,0.0001],"n_estimators":np.arange(10,100,10)}
grid = GridSearchCV(AdaBoostClassifier(),param_grid=tune_parameters,cv=5,scoring="accuracy").fit(X_train,y_train)

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 90}

# %%
adaboost_model = AdaBoostClassifier(learning_rate= 0.1, n_estimators= 90).fit(X_train,y_train)
y_pred = adaboost_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8532608695652174

# %% [markdown]
# * As we can see, the accuracy of the overall model has been reduced after doing hyperparameter tuning.
# * So can ignore Hyperparameter tuning.

# %% [markdown]
# <a id="scaling"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Scaling numerical features using Standard Scaler
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
scaler = StandardScaler()

# %%
X_scaled = pd.DataFrame(scaler.fit_transform(X),columns=X.columns)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=2)

# %%
adaboost_model = AdaBoostClassifier().fit(X_train,y_train)
y_pred = adaboost_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9130434782608695

# %% [markdown]
# * Scaling the independent features have improved our efficiency.

# %% [markdown]
# <a id="interpretation"></a>
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>Interpretation</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <a id="interpretation"></a>
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>1. AdaBoost Classifier Dominates</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# The AdaBoost classifier outperformed all other models in predicting employee attrition. Its high accuracy and robust generalization demonstrate its ability to effectively identify employees at risk of leaving the company. This suggests that ensemble methods like AdaBoost are well-suited for this task, as they can combine the strengths of multiple weak learners to make more accurate predictions.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>2. Important Features</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# During our feature selection and engineering processes, we identified several key features that strongly influence employee attrition. Notably, job satisfaction, work-life balance, and performance rating emerged as critical factors. Employees with higher job satisfaction and better work-life balance were less likely to leave the company, while those with lower performance ratings were more prone to attrition. Understanding these influential attributes can guide organizations in prioritizing areas for improvement to reduce attrition rates.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>3. Business Insights</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# Our analysis provides actionable insights for businesses. For instance, by focusing on improving job satisfaction, work-life balance, and performance ratings, organizations can enhance employee retention. Implementing targeted retention strategies, such as providing professional development opportunities or work-life balance programs, can have a positive impact on workforce stability.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>4. Continuous Monitoring</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# Employee attrition is an ongoing concern for organizations. Our predictive model, based on the AdaBoost classifier, can be integrated into HR systems to continuously monitor and identify employees at risk of leaving. This proactive approach allows organizations to address attrition issues in real-time, reducing the need for reactive measures such as frequent recruitment.
#
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=4px>
#                     <b>5. Ethical Considerations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# When implementing predictive models for HR purposes, it's crucial to consider ethical aspects such as fairness and bias. Organizations should ensure that the models do not discriminate against any demographic groups and that they comply with legal and ethical standards for employee data use.
#
# In conclusion, the interpretation of our project's results highlights the significance of the AdaBoost classifier in predicting employee attrition and underscores the importance of key attributes such as job satisfaction, work-life balance, and performance ratings. By leveraging these insights, organizations can make informed decisions to retain their valuable workforce and foster a more stable and motivated working environment. Continuous monitoring and ethical considerations are essential aspects of deploying predictive models in HR management.

# %% [markdown]
# <a id="fit"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Overall Fit of the model
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
y_pred_test = adaboost_model.predict(X_test)
y_pred_train = adaboost_model.predict(X_train)

# %%
print("Accuracy of test set: ",accuracy_score(y_test,y_pred_test))
print("Accuracy of train set: ",accuracy_score(y_train,y_pred_train))
# Out:
# Accuracy of test set:  0.9130434782608695
# Accuracy of train set:  0.897680763983629

# %% [markdown]
# * Since the model has performed good in both training and test set, it has generalized well.
# * We can conclude that the model is well fit.

# %% [markdown]
# <a id="conclusion"><a>
# <table align="center" width=100%>
#     <tr>
#         <td>
#             <div align="left">
#                 <font color="#21619" size=5px>
#                     <b>  Conclusion
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# In this project, a journey was undertaken to predict employee attrition and equip organizations with data-driven insights to reduce turnover and enhance workforce stability. Through a comprehensive pipeline of data exploration, preprocessing, feature engineering, and model development, valuable insights and predictions were achieved.
#
# The findings indicate that the AdaBoost classifier emerged as the shining star among a diverse set of machine learning algorithms. It was observed to exhibit outstanding performance in predicting employee attrition, showcasing its ability to effectively identify employees at risk of leaving the company. This robust model can serve as a powerful tool for organizations seeking to proactively manage attrition and implement targeted retention strategies.
#
# Additionally, data exploration and feature engineering efforts allowed for a deeper understanding of the factors influencing attrition, providing actionable insights for HR and management teams. It was noted that certain attributes such as job satisfaction, work-life balance, and performance rating played pivotal roles in employee attrition.
#
# In conclusion, this project demonstrates the potential of machine learning in addressing real-world workforce challenges. By leveraging the insights gained from data analysis and the predictive capabilities of the AdaBoost classifier, organizations can take proactive measures to retain valuable talent, reduce recruitment costs, and maintain a motivated and productive workforce.
